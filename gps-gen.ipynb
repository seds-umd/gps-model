# %%
import numpy as np
import matplotlib.pyplot as plt
import prn

# %%
def generate_gps(f_s: int, n: int, sv: int, doppler: float = 0, code_phase: int = 0, snr: float = None):
    """Generate a modulated baseband GPS signal.

    Args:
        f_s (int): Sampling frequency, must be greater than 2*1.023 MHz
        n (int): Number of samples to generate
        sv (int): Satellite index, between 1 and 32 inclusive
        doppler (float): Frequency shift of signal
        code_phase (int): Offset of PRN code
        snr (float): SNR of output signal. If not given, no noise is generated.
    """
    return
